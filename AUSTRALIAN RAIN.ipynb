# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from tqdm.notebook import tqdm
from sklearn.model_selection import train_test_split

plt.style.use('seaborn')

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

import torch
from torch import nn
import torch.nn.functional as F
from torchsummary import summary

# %%
df = pd.read_csv('/weatherAUS 2.csv')
df.drop('Date', inplace=True, axis=1)
df.drop('Evaporation', inplace=True, axis=1)
df.drop('Sunshine', inplace=True, axis=1)
df.drop('Cloud9am', inplace=True, axis=1)
df.drop('Cloud3pm', inplace=True, axis=1)
df.head(10)
# Out:
#   Location  MinTemp  MaxTemp  Rainfall  ... Temp9am  Temp3pm RainToday RainTomorrow
# 0   Albury     13.4     22.9       0.6  ...    16.9     21.8        No           No
# 1   Albury      7.4     25.1       0.0  ...    17.2     24.3        No           No
# 2   Albury     12.9     25.7       0.0  ...    21.0     23.2        No           No
# 3   Albury      9.2     28.0       0.0  ...    18.1     26.5        No           No
# 4   Albury     17.5     32.3       1.0  ...    17.8     29.7        No           No
# 5   Albury     14.6     29.7       0.2  ...    20.6     28.9        No           No
# 6   Albury     14.3     25.0       0.0  ...    18.1     24.6        No           No
# 7   Albury      7.7     26.7       0.0  ...    16.3     25.5        No           No
# 8   Albury      9.7     31.9       0.0  ...    18.3     30.2        No          Yes
# 9   Albury     13.1     30.1       1.4  ...    20.1     28.2       Yes           No
#
# [10 rows x 18 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145460 entries, 0 to 145459
# Data columns (total 18 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   Location       145460 non-null  object
#  1   MinTemp        143975 non-null  float64
#  2   MaxTemp        144199 non-null  float64
#  3   Rainfall       142199 non-null  float64
#  4   WindGustDir    135134 non-null  object
#  5   WindGustSpeed  135197 non-null  float64
#  6   WindDir9am     134894 non-null  object
#  7   WindDir3pm     141232 non-null  object
#  8   WindSpeed9am   143693 non-null  float64
#  9   WindSpeed3pm   142398 non-null  float64
#  10  Humidity9am    142806 non-null  float64
#  11  Humidity3pm    140953 non-null  float64
#  12  Pressure9am    130395 non-null  float64
#  13  Pressure3pm    130432 non-null  float64
#  14  Temp9am        143693 non-null  float64
#  15  Temp3pm        141851 non-null  float64
#  16  RainToday      142199 non-null  object
#  17  RainTomorrow   142193 non-null  object
# dtypes: float64(12), object(6)
# memory usage: 20.0+ MB

# %%
df['RainTomorrow'].replace("No", 0, inplace=True)
df['RainTomorrow'].replace("Yes", 1, inplace=True) 
df.dropna(subset=['RainTomorrow'], inplace=True)
df
# Out:
#        Location  MinTemp  MaxTemp  ...  Temp3pm RainToday  RainTomorrow
# 0        Albury     13.4     22.9  ...     21.8        No           0.0
# 1        Albury      7.4     25.1  ...     24.3        No           0.0
# 2        Albury     12.9     25.7  ...     23.2        No           0.0
# 3        Albury      9.2     28.0  ...     26.5        No           0.0
# 4        Albury     17.5     32.3  ...     29.7        No           0.0
# ...         ...      ...      ...  ...      ...       ...           ...
# 145454    Uluru      3.5     21.8  ...     20.9        No           0.0
# 145455    Uluru      2.8     23.4  ...     22.4        No           0.0
# 145456    Uluru      3.6     25.3  ...     24.5        No           0.0
# 145457    Uluru      5.4     26.9  ...     26.1        No           0.0
# 145458    Uluru      7.8     27.0  ...     26.0        No           0.0
#
# [142193 rows x 18 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 142193 entries, 0 to 145458
# Data columns (total 18 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   Location       142193 non-null  object
#  1   MinTemp        141556 non-null  float64
#  2   MaxTemp        141871 non-null  float64
#  3   Rainfall       140787 non-null  float64
#  4   WindGustDir    132863 non-null  object
#  5   WindGustSpeed  132923 non-null  float64
#  6   WindDir9am     132180 non-null  object
#  7   WindDir3pm     138415 non-null  object
#  8   WindSpeed9am   140845 non-null  float64
#  9   WindSpeed3pm   139563 non-null  float64
#  10  Humidity9am    140419 non-null  float64
#  11  Humidity3pm    138583 non-null  float64
#  12  Pressure9am    128179 non-null  float64
#  13  Pressure3pm    128212 non-null  float64
#  14  Temp9am        141289 non-null  float64
#  15  Temp3pm        139467 non-null  float64
#  16  RainToday      140787 non-null  object
#  17  RainTomorrow   142193 non-null  float64
# dtypes: float64(13), object(5)
# memory usage: 20.6+ MB

# %%
object_columns = list(df.select_dtypes("object").columns)
object_columns
df_2 = pd.DataFrame()
for column in object_columns:
    df_2 = pd.concat([df_2, pd.get_dummies(df[column], prefix=column)], axis=1)
df_2
# Out:
#         Location_Adelaide  Location_Albany  ...  RainToday_No  RainToday_Yes
# 0                       0                0  ...             1              0
# 1                       0                0  ...             1              0
# 2                       0                0  ...             1              0
# 3                       0                0  ...             1              0
# 4                       0                0  ...             1              0
# ...                   ...              ...  ...           ...            ...
# 145454                  0                0  ...             1              0
# 145455                  0                0  ...             1              0
# 145456                  0                0  ...             1              0
# 145457                  0                0  ...             1              0
# 145458                  0                0  ...             1              0
#
# [142193 rows x 99 columns]

# %%
# Создаем новый датафрейм, объединяя исходный датафрейм с новым. 
df_3 = pd.concat([df.select_dtypes(exclude='object'), df_2], axis=1)

df_3
# Out:
#         MinTemp  MaxTemp  Rainfall  ...  WindDir3pm_WSW  RainToday_No  RainToday_Yes
# 0          13.4     22.9       0.6  ...               0             1              0
# 1           7.4     25.1       0.0  ...               1             1              0
# 2          12.9     25.7       0.0  ...               1             1              0
# 3           9.2     28.0       0.0  ...               0             1              0
# 4          17.5     32.3       1.0  ...               0             1              0
# ...         ...      ...       ...  ...             ...           ...            ...
# 145454      3.5     21.8       0.0  ...               0             1              0
# 145455      2.8     23.4       0.0  ...               0             1              0
# 145456      3.6     25.3       0.0  ...               0             1              0
# 145457      5.4     26.9       0.0  ...               0             1              0
# 145458      7.8     27.0       0.0  ...               0             1              0
#
# [142193 rows x 112 columns]

# %%
df_3.drop('RainTomorrow', inplace=True, axis=1)
df_3.head(10)
# Out:
#    MinTemp  MaxTemp  Rainfall  ...  WindDir3pm_WSW  RainToday_No  RainToday_Yes
# 0     13.4     22.9       0.6  ...               0             1              0
# 1      7.4     25.1       0.0  ...               1             1              0
# 2     12.9     25.7       0.0  ...               1             1              0
# 3      9.2     28.0       0.0  ...               0             1              0
# 4     17.5     32.3       1.0  ...               0             1              0
# 5     14.6     29.7       0.2  ...               0             1              0
# 6     14.3     25.0       0.0  ...               0             1              0
# 7      7.7     26.7       0.0  ...               0             1              0
# 8      9.7     31.9       0.0  ...               0             1              0
# 9     13.1     30.1       1.4  ...               0             0              1
#
# [10 rows x 111 columns]

# %%
df_3.iloc[:, :20].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 142193 entries, 0 to 145458
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   MinTemp                 141556 non-null  float64
#  1   MaxTemp                 141871 non-null  float64
#  2   Rainfall                140787 non-null  float64
#  3   WindGustSpeed           132923 non-null  float64
#  4   WindSpeed9am            140845 non-null  float64
#  5   WindSpeed3pm            139563 non-null  float64
#  6   Humidity9am             140419 non-null  float64
#  7   Humidity3pm             138583 non-null  float64
#  8   Pressure9am             128179 non-null  float64
#  9   Pressure3pm             128212 non-null  float64
#  10  Temp9am                 141289 non-null  float64
#  11  Temp3pm                 139467 non-null  float64
#  12  Location_Adelaide       142193 non-null  uint8
#  13  Location_Albany         142193 non-null  uint8
#  14  Location_Albury         142193 non-null  uint8
#  15  Location_AliceSprings   142193 non-null  uint8
#  16  Location_BadgerysCreek  142193 non-null  uint8
#  17  Location_Ballarat       142193 non-null  uint8
#  18  Location_Bendigo        142193 non-null  uint8
#  19  Location_Brisbane       142193 non-null  uint8
# dtypes: float64(12), uint8(8)
# memory usage: 15.2 MB

# %%
df_3['MinTemp'].fillna(df_3['MinTemp'].mean(), inplace=True)
df_3['MaxTemp'].fillna(df_3['MaxTemp'].mean(), inplace=True)
df_3['Rainfall'].fillna(df_3['Rainfall'].mean(), inplace=True)
df_3['WindGustSpeed'].fillna(df_3['WindGustSpeed'].mean(), inplace=True)
df_3['WindSpeed9am'].fillna(df_3['WindSpeed9am'].mean(), inplace=True)
df_3['WindSpeed3pm'].fillna(df_3['WindSpeed3pm'].mean(), inplace=True)
df_3['Humidity9am'].fillna(df_3['Humidity9am'].mean(), inplace=True)
df_3['Humidity3pm'].fillna(df_3['Humidity3pm'].mean(), inplace=True)
df_3['Pressure9am'].fillna(df_3['Pressure9am'].mean(), inplace=True)
df_3['Pressure3pm'].fillna(df_3['Pressure3pm'].mean(), inplace=True)
df_3['Temp9am'].fillna(df_3['Temp9am'].mean(), inplace=True)
df_3['Temp3pm'].fillna(df_3['Temp3pm'].mean(), inplace=True)
df_3
# Out:
#         MinTemp  MaxTemp  Rainfall  ...  WindDir3pm_WSW  RainToday_No  RainToday_Yes
# 0          13.4     22.9       0.6  ...               0             1              0
# 1           7.4     25.1       0.0  ...               1             1              0
# 2          12.9     25.7       0.0  ...               1             1              0
# 3           9.2     28.0       0.0  ...               0             1              0
# 4          17.5     32.3       1.0  ...               0             1              0
# ...         ...      ...       ...  ...             ...           ...            ...
# 145454      3.5     21.8       0.0  ...               0             1              0
# 145455      2.8     23.4       0.0  ...               0             1              0
# 145456      3.6     25.3       0.0  ...               0             1              0
# 145457      5.4     26.9       0.0  ...               0             1              0
# 145458      7.8     27.0       0.0  ...               0             1              0
#
# [142193 rows x 111 columns]

# %%
target = 'RainTomorrow'
x = df_3[:].to_numpy()
y = df[target]
x.shape, y.shape
# Out:
# ((142193, 111), (142193,))

# %%
x_train, x_valid, y_train, y_valid = train_test_split(x, y, test_size=0.25, random_state=1)
x_train.shape, x_valid.shape, y_train.shape, y_valid.shape
# Out:
# ((106644, 111), (35549, 111), (106644,), (35549,))

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
x_train_norm = scaler.fit_transform(x_train)
x_valid_norm = scaler.transform(x_valid)
x_train_norm.shape, x_valid_norm.shape
# Out:
# ((106644, 111), (35549, 111))

# %%
input_shape = x_train_norm.shape[1]
input_shape
# Out:
# 111

# %%
class HistoryCallback(keras.callbacks.Callback):
    def __init__(self):
        self.epochs = 0
        self.train_loss = []
        self.train_auc = []
        self.val_loss = []
        self.val_auc = []
        
        # %matplotlib inline
        
    def on_epoch_end(self, epoch, logs=None):
        self.epochs += 1
        self.train_loss.append(logs['loss'])
        self.train_auc.append(logs['auc'])
        self.val_loss.append(logs['val_loss'])
        self.val_auc.append(logs['val_auc'])
        
    def on_train_end(self, epoch, logs=None):
        self.plot()
        
    def plot(self):
        fig, ax = plt.subplots(1,2, figsize=(10,5))
        
        ax[0].plot(self.train_loss, label='train loss')
        ax[0].plot(self.val_loss, label='val loss')
        ax[0].legend()
        ax[0].set_title('Loss')
        ax[1].plot(self.train_auc, label='train auc')
        ax[1].plot(self.val_auc, label='val auc')
        ax[1].legend()
        ax[1].set_title(f"AUC: {np.mean(self.val_auc)}")
        plt.show()

# %%
model = keras.Sequential(
    [
        keras.Input(shape=input_shape),
        layers.Dense(200, activation='sigmoid'),
        layers.Dense(200, activation='sigmoid'),
        layers.Dense(1, activation='sigmoid')
    ]
)

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 200)               22400
# _________________________________________________________________
# dense_1 (Dense)              (None, 200)               40200
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 201
# =================================================================
# Total params: 62,801
# Trainable params: 62,801
# Non-trainable params: 0
# _________________________________________________________________

# %%
tf.keras.backend.clear_session()

# %%
model.compile(
    loss=tf.keras.losses.BinaryCrossentropy(),
    metrics=[tf.keras.metrics.AUC()],
    optimizer=keras.optimizers.Adam(lr=0.005)
)

# %%
history = HistoryCallback()

# %%
early_stopping = keras.callbacks.EarlyStopping(
    monitor="val_loss", # по какому параметру будем останавливать
    patience=10, # сколько эпох подряд качество не должно улучшаться для остановки
    restore_best_weights=False # также можно восстанавливать лучшие веса после остановки (откатываться на 5 эпох назад)
)

# %%
history_ = model.fit(
    x_train_norm,
    y_train,
    batch_size=10000,
    validation_data=(x_valid_norm, y_valid),
    callbacks=[history, early_stopping],
    initial_epoch=history.epochs, # сколько эпох уже прошло
    epochs=history.epochs + 50, # сколько эпох должно получиться всего - с учет уже пройденных эпох в параметре inital_epoch
    verbose=1, # 0-ничего, 1-progress bar, 2-без бара
    use_multiprocessing=True, # 
);
# Out:
# Epoch 1/50
# 11/11 [==============================] - 3s 150ms/step - loss: 0.6111 - auc: 0.5516 - val_loss: 0.5018 - val_auc: 0.7722
# Epoch 2/50
# 11/11 [==============================] - 1s 119ms/step - loss: 0.4716 - auc: 0.7549 - val_loss: 0.4176 - val_auc: 0.8191
# Epoch 3/50
# 11/11 [==============================] - 1s 119ms/step - loss: 0.4135 - auc: 0.8163 - val_loss: 0.3911 - val_auc: 0.8380
# Epoch 4/50
# 11/11 [==============================] - 1s 120ms/step - loss: 0.3926 - auc: 0.8376 - val_loss: 0.3770 - val_auc: 0.8496
# Epoch 5/50
# 11/11 [==============================] - 1s 120ms/step - loss: 0.3767 - auc: 0.8495 - val_loss: 0.3684 - val_auc: 0.8568
# Epoch 6/50
# 11/11 [==============================] - 1s 122ms/step - loss: 0.3705 - auc: 0.8557 - val_loss: 0.3633 - val_auc: 0.8595
# Epoch 7/50
# 11/11 [==============================] - 1s 121ms/step - loss: 0.3635 - auc: 0.8598 - val_loss: 0.3600 - val_auc: 0.8616
# Epoch 8/50
# 11/11 [==============================] - 1s 121ms/step - loss: 0.3621 - auc: 0.8622 - val_loss: 0.3566 - val_auc: 0.8646
# Epoch 9/50
# 11/11 [==============================] - 1s 120ms/step - loss: 0.3578 - auc: 0.8644 - val_loss: 0.3532 - val_auc: 0.8677
# Epoch 10/50
# 11/11 [==============================] - 1s 120ms/step - loss: 0.3530 - auc: 0.8704 - val_loss: 0.3491 - val_auc: 0.8710
# Epoch 11/50
# 11/11 [==============================] - 1s 120ms/step - loss: 0.3494 - auc: 0.8721 - val_loss: 0.3460 - val_auc: 0.8740
# Epoch 12/50
# 11/11 [==============================] - 1s 121ms/step - loss: 0.3449 - auc: 0.8750 - val_loss: 0.3420 - val_auc: 0.8771
# Epoch 13/50
# 11/11 [==============================] - 1s 122ms/step - loss: 0.3408 - auc: 0.8789 - val_loss: 0.3391 - val_auc: 0.8796
# Epoch 14/50
# 11/11 [==============================] - 1s 121ms/step - loss: 0.3379 - auc: 0.8820 - val_loss: 0.3360 - val_auc: 0.8824
# Epoch 15/50
# 11/11 [==============================] - 1s 119ms/step - loss: 0.3337 - auc: 0.8846 - val_loss: 0.3343 - val_auc: 0.8839
# Epoch 16/50
# 11/11 [==============================] - 1s 120ms/step - loss: 0.3294 - auc: 0.8880 - val_loss: 0.3319 - val_auc: 0.8860
# Epoch 17/50
# 11/11 [==============================] - 1s 120ms/step - loss: 0.3286 - auc: 0.8889 - val_loss: 0.3322 - val_auc: 0.8867
# Epoch 18/50
# 11/11 [==============================] - 1s 120ms/step - loss: 0.3265 - auc: 0.8911 - val_loss: 0.3294 - val_auc: 0.8875
# Epoch 19/50
# 11/11 [==============================] - 1s 119ms/step - loss: 0.3240 - auc: 0.8933 - val_loss: 0.3280 - val_auc: 0.8887
# Epoch 20/50
# 11/11 [==============================] - 1s 118ms/step - loss: 0.3184 - auc: 0.8965 - val_loss: 0.3268 - val_auc: 0.8905
# Epoch 21/50
# 11/11 [==============================] - 1s 117ms/step - loss: 0.3207 - auc: 0.8947 - val_loss: 0.3270 - val_auc: 0.8906
# Epoch 22/50
# 11/11 [==============================] - 1s 122ms/step - loss: 0.3158 - auc: 0.8992 - val_loss: 0.3246 - val_auc: 0.8913
# Epoch 23/50
# 11/11 [==============================] - 1s 118ms/step - loss: 0.3147 - auc: 0.9005 - val_loss: 0.3244 - val_auc: 0.8915
# Epoch 24/50
# 11/11 [==============================] - 1s 119ms/step - loss: 0.3133 - auc: 0.9007 - val_loss: 0.3237 - val_auc: 0.8921
# Epoch 25/50
# 11/11 [==============================] - 1s 120ms/step - loss: 0.3106 - auc: 0.9029 - val_loss: 0.3240 - val_auc: 0.8919
# Epoch 26/50
# 11/11 [==============================] - 1s 120ms/step - loss: 0.3077 - auc: 0.9042 - val_loss: 0.3239 - val_auc: 0.8922
# Epoch 27/50
# 11/11 [==============================] - 1s 118ms/step - loss: 0.3063 - auc: 0.9058 - val_loss: 0.3251 - val_auc: 0.8921
# Epoch 28/50
# 11/11 [==============================] - 1s 119ms/step - loss: 0.3026 - auc: 0.9077 - val_loss: 0.3243 - val_auc: 0.8918
# Epoch 29/50
# 11/11 [==============================] - 1s 121ms/step - loss: 0.3033 - auc: 0.9070 - val_loss: 0.3250 - val_auc: 0.8921
# Epoch 30/50
# 11/11 [==============================] - 1s 124ms/step - loss: 0.3018 - auc: 0.9093 - val_loss: 0.3253 - val_auc: 0.8916
# Epoch 31/50
# 11/11 [==============================] - 1s 122ms/step - loss: 0.2977 - auc: 0.9112 - val_loss: 0.3248 - val_auc: 0.8919
# Epoch 32/50
# 11/11 [==============================] - 1s 120ms/step - loss: 0.2971 - auc: 0.9111 - val_loss: 0.3263 - val_auc: 0.8908
# Epoch 33/50
# 11/11 [==============================] - 1s 120ms/step - loss: 0.2956 - auc: 0.9122 - val_loss: 0.3277 - val_auc: 0.8907
# Epoch 34/50
# 11/11 [==============================] - 1s 120ms/step - loss: 0.2935 - auc: 0.9135 - val_loss: 0.3290 - val_auc: 0.8903
